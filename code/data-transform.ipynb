# %%
import pandas as pd
import re
from pathlib import Path

def parse_duration(d):
    match = re.match(r'PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?', d)
    hours = int(match.group(1) or 0)
    minutes = int(match.group(2) or 0)
    seconds = int(match.group(3) or 0)
    return f"{hours:02}:{minutes:02}:{seconds:02}"

df=pd.read_json('../datastore/videos.json')
display(df)
df['publishedAt']=pd.to_datetime(df['publishedAt']).dt.tz_localize(None)
df['duration'] = df['duration'].apply(parse_duration)
display(df.head(50))

if not Path('../datastore/videos_list.xlsx').exists():
    df.to_excel('../datastore/videos_list.xlsx',index_label='id')
# Out:
#          videoId                                              title  \
# 0    s79YFLmZRlY  Learn Data & AI Skills for FREE! Spring Skillu...
# 1    K9Y8P3X45kE  SQL JOINs | INNER vs LEFT vs RIGHT vs FULL OUT...
# 2    QLIdF4nPUk4                       Learn SQL: Primary Keys #sql
# 3    7ZWp03QAU_Q  Master new skills & level up your data + AI kn...
# 4    qQ51wuIgM7E  Excel vs Power BI vs SQL vs Python | Restauran...
# ..           ...                                                ...
# 673  p6S9Gr1e4DQ              Learn Microsoft Excel Charts & Graphs
# 674  c9KyB0IrRCc         Learn Microsoft Excel Formulas & Functions
# 675  8_-RNgldpZI           Data Visualization with Tables vs Charts
# 676  ztqDCnAjrWo                   Why Learn Business Intelligence?
# 677  ZicVaFh8yoY            Maven Analytics: Become a DATA ROCKSTAR
#
#               publishedAt duration  viewCount  likeCount  commentCount
# 0    2026-04-27T16:15:51Z    PT20S       1349         14             0
# 1    2026-04-22T14:00:35Z  PT9M19S       2419        149             4
# 2    2026-04-21T14:00:40Z  PT1M39S       5949        232             4
# 3    2026-04-20T14:00:11Z    PT39S       2397         50             0
# 4    2026-04-15T14:01:32Z  PT21M4S     118808       3177           196
# ..                    ...      ...        ...        ...           ...
# 673  2021-01-26T15:00:17Z  PT1M19S       1261         13             0
# 674  2021-01-23T15:21:55Z  PT1M20S       5888         54             4
# 675  2020-10-07T17:25:54Z  PT1M31S       1160         17             0
# 676  2020-10-07T17:16:17Z  PT3M56S        397         19             0
# 677  2020-09-14T14:27:32Z   PT2M1S       3946         66             2
#
# [678 rows x 7 columns]
#         videoId                                              title  \
# 0   s79YFLmZRlY  Learn Data & AI Skills for FREE! Spring Skillu...
# 1   K9Y8P3X45kE  SQL JOINs | INNER vs LEFT vs RIGHT vs FULL OUT...
# 2   QLIdF4nPUk4                       Learn SQL: Primary Keys #sql
# 3   7ZWp03QAU_Q  Master new skills & level up your data + AI kn...
# 4   qQ51wuIgM7E  Excel vs Power BI vs SQL vs Python | Restauran...
# 5   w0cjwIR9O7E   Learn Tableau: Sheet Swapping with Text #tableau
# 6   YaMvfOueBq8              Learn Python: Dummy Variables #python
# 7   4HW7KeLtPmc  Stop Using AI as a Search Engine: Build Custom...
# 8   r80gLbQSTG0   Learn Excel: Data Label For The Max Value #excel
# 9   PyQqiyIO60I               Learn Tableau: Extract Hack #tableau
# 10  D7rEhg13Ac0  Learn SQL: How to Filter Your Data Using the W...
# 11  Ob_iiDOaGy4    Learn Excel: Aggregate Time Data w/ Text #excel
# 12  Si5jn3Ca13c     Why your presentations are failing...  #Shorts
# 13  _4SkiHcooEg  Why Your Presentations Fail (Even When Your Da...
# 14  cZ7lGdPYnys           Stop writing your own prompts. 🛑 #shorts
# 15  cGVnkw3qW2U           Can AI catch our mistake? 🤨 #datascience
# 16  henJv1DH2Ys  Text Classification with AI: The Easiest Way t...
# 17  Vd2V0fshbOU  Learn Python: Binning Data Using The Cut Funct...
# 18  dM6E7EA3K-g  Excel Showdown | Power Query vs Formulas vs Co...
# 19  F-DGqVuZGW4                  Learn Data: Context is King #data
# 20  0JZisMktcbA  How to Write the Perfect AI Prompt: Meta-Promp...
# 21  cB9-P7MFAXI               Learn Excel: Very Hidden Tabs #excel
# 22  p7zfbS8q928  Get LIFETIME Access to Maven Analytic +$1000 A...
# 23  eRWOdpludPM  Getting Started with SQL | SELECT, FROM, WHERE...
# 24  kwJ9lMUXOSQ  $1000 OFF Maven Analytics + Analyst Builder LI...
# 25  p_vQGFVujB0  How to Ace Your Data Job Interview (w/ "Alex t...
# 26  kmTBohyePNE  Storytelling for  Business Presentations (NEW ...
# 27  0G2z3QDMBZA  What hiring managers ACTUALLY look for in an i...
# 28  AiSis_eUHHc                    Learn Python: Transpose #python
# 29  DqRVY9L9Ows                   How Will AI Impact Data Careers?
# 30  SJh8EUkOUZU        Pro Tip: Look at your data regularly! #data
# 31  uZ--1PSofR8          Learn Power BI: Sort Month Names #powerbi
# 32  6_YO6yOG2_8  Learn Python: Create Simple & Clear Data Visua...
# 33  oHOUoCVJ5ik  When presenting data, speak your audience’s la...
# 34  PVF5aPjCNLc     This or That with Data Analytics Experts #data
# 35  PDgtKkuHxu0  Master AI Prompt Writing in 1 Hour | The BRIDG...
# 36  YKUskD8CUxk  "Data Storytelling is often the missing link i...
# 37  dbCgIdniZSU               Learn Python: Tornado Charts #python
# 38  FjxtntY5sO0  How to Join Tables in SQL | Clearly Explained ...
# 39  omTTLdHvgHA                  Learn Excel: Unpivot Data! #excel
# 40  DY27yuiQRAY      Learn Python: Time Series Forecasting #python
# 41  E8Ts4ilL46Q  How to Use AI to Prep for Your Next Data Job I...
# 42  sjQY6DmHuM0     Learn Excel: Create Charts Inside Cells #excel
# 43  8Rn4dqgpNwY  Excel Pivot Tables: How to Create Raw Data in ...
# 44  Z2dPNiz6giI  How to Transform Your LinkedIn Profile with AI...
# 45  --OrmVkJbXc              Learn Python: Method Chaining #python
# 46  80nb95SAagw  January Jumpstart is LIVE! Learn Data & AI Ski...
# 47  P0VNg64f1hY  How to Use AI to Build Your Data Project Portf...
# 48  wTKT18kmWzI  9 Essential Chart Types for Data Analysts | Da...
# 49  3Rj1h8UzdQs                 Learn SQL: The IN( ) Operator #sql
#
#            publishedAt  duration  viewCount  likeCount  commentCount
# 0  2026-04-27 16:15:51  00:00:20       1349         14             0
